# %%
import pandas as pd 
import numpy as np
import os
import matplotlib

# %%
time_line_cnn = pd.read_csv('/Users/sandrobarreshamers/github/krweb/Query_files/time_line_cnn.csv')
print(time_line_cnn)
# Out:
#                           event             datetime  \
# 0    http://example.com/E_CNN_1  2021-01-06T07:30:00
# 1    http://example.com/E_CNN_2  2021-01-06T09:24:00
# 2    http://example.com/E_CNN_3  2021-01-06T09:52:00
# 3    http://example.com/E_CNN_4  2021-01-06T10:00:00
# 4    http://example.com/E_CNN_5  2021-01-06T10:15:00
# 5    http://example.com/E_CNN_6  2021-01-06T10:47:00
# 6    http://example.com/E_CNN_7  2021-01-06T11:20:00
# 7    http://example.com/E_CNN_8  2021-01-06T12:00:00
# 8    http://example.com/E_CNN_9  2021-01-06T12:00:00
# 9   http://example.com/E_CNN_10  2021-01-06T13:00:00
# 10  http://example.com/E_CNN_11  2021-01-06T13:10:00
# 11  http://example.com/E_CNN_12  2021-01-06T13:19:00
# 12  http://example.com/E_CNN_13  2021-01-06T13:25:00
# 13  http://example.com/E_CNN_14  2021-01-06T13:39:00
# 14  http://example.com/E_CNN_15  2021-01-06T14:00:00
# 15  http://example.com/E_CNN_16  2021-01-06T14:03:00
# 16  http://example.com/E_CNN_17  2021-01-06T14:13:00
# 17  http://example.com/E_CNN_18  2021-01-06T14:14:00
# 18  http://example.com/E_CNN_19  2021-01-06T14:15:00
# 19  http://example.com/E_CNN_20  2021-01-06T14:24:00
# 20  http://example.com/E_CNN_21  2021-01-06T14:26:00
# 21  http://example.com/E_CNN_22  2021-01-06T14:28:00
# 22  http://example.com/E_CNN_23  2021-01-06T14:28:00
# 23  http://example.com/E_CNN_24  2021-01-06T14:30:00
# 24  http://example.com/E_CNN_25  2021-01-06T14:32:00
# 25  http://example.com/E_CNN_26  2021-01-06T14:35:00
# 26  http://example.com/E_CNN_27  2021-01-06T14:38:00
# 27  http://example.com/E_CNN_28  2021-01-06T14:39:00
# 28  http://example.com/E_CNN_29  2021-01-06T14:40:00
# 29  http://example.com/E_CNN_30  2021-01-06T14:44:00
# 30  http://example.com/E_CNN_31  2021-01-06T14:45:00
# 31  http://example.com/E_CNN_32  2021-01-06T14:53:00
# 32  http://example.com/E_CNN_33  2021-01-06T15:00:00
# 33  http://example.com/E_CNN_34  2021-01-06T15:00:00
# 34  http://example.com/E_CNN_36  2021-01-06T15:09:00
# 35  http://example.com/E_CNN_37  2021-01-06T15:13:00
# 36  http://example.com/E_CNN_38  2021-01-06T15:15:00
# 37  http://example.com/E_CNN_39  2021-01-06T15:31:00
# 38  http://example.com/E_CNN_40  2021-01-06T16:03:00
# 39  http://example.com/E_CNN_41  2021-01-06T16:03:00
# 40  http://example.com/E_CNN_42  2021-01-06T16:05:00
# 41  http://example.com/E_CNN_43  2021-01-06T16:15:00
# 42  http://example.com/E_CNN_44  2021-01-06T16:17:00
# 43  http://example.com/E_CNN_45  2021-01-06T16:45:00
# 44  http://example.com/E_CNN_46  2021-01-06T18:00:00
# 45  http://example.com/E_CNN_47  2021-01-06T18:01:00
# 46  http://example.com/E_CNN_48  2021-01-06T18:27:00
# 47  http://example.com/E_CNN_49  2021-01-06T19:02:00
# 48  http://example.com/E_CNN_50  2021-01-06T19:14:00
# 49  http://example.com/E_CNN_51  2021-01-06T20:00:00
# 50  http://example.com/E_CNN_52  2021-01-06T20:39:00
# 51  http://example.com/E_CNN_53  2021-01-06T21:02:00
# 52  http://example.com/E_CNN_54  2021-01-06T21:23:00
# 53  http://example.com/E_CNN_55  2021-01-06T22:11:00
# 54  http://example.com/E_CNN_56  2021-01-06T22:19:00
# 55  http://example.com/E_CNN_57  2021-01-06T23:08:00
# 56  http://example.com/E_CNN_58  2021-01-06T23:10:00
#
#                       location  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3   http://example.com/ellipse
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# 30                         NaN
# 31                         NaN
# 32                         NaN
# 33                         NaN
# 34                         NaN
# 35                         NaN
# 36                         NaN
# 37                         NaN
# 38                         NaN
# 39                         NaN
# 40                         NaN
# 41                         NaN
# 42                         NaN
# 43                         NaN
# 44                         NaN
# 45                         NaN
# 46                         NaN
# 47                         NaN
# 48                         NaN
# 49                         NaN
# 50                         NaN
# 51                         NaN
# 52                         NaN
# 53                         NaN
# 54                         NaN
# 55                         NaN
# 56                         NaN
#
#                                           description
# 0   Meadows texts Rep. Jim Jordan, an Ohio Republi...
# 1   Trump talks on the phone with Jordan for appro...
# 2   Trump talks to senior adviser and lead speechw...
# 3   White House deputy chief of staff Tony Ornato ...
# 4   Hutchinson and Ornato inform Meadows about the...
# 5   Trump lawyer Rudy Giuliani begins his speech a...
# 6   Trump speaks on the phone with Pence. White Ho...
# 7   Trump tells his staff to 'take the f**king mag...
# 8   Trump begins his speech at the Ellipse, where ...
# 9   Pro-Trump rioters – including members of the P...
# 10  As he ends his speech at the Ellipse, Trump ca...
# 11  Trump arrives back at the White House. During ...
# 12  Trump goes into the private dining room near t...
# 13  Trump calls Giuliani, according to phone recor...
# 14  The Capitol goes on lockdown as some of the fi...
# 15  Trump calls Giuliani again, and the call lasts...
# 16  The Senate abruptly adjourns, amid a debate ov...
# 17  In one of the most infamous scenes of the insu...
# 18  At the White House, Cipollone again tells Mead...
# 19  Trump criticizes Pence in a tweet, slamming Pe...
# 20  The Secret Service evacuates Pence from his of...
# 21                                                NaN
# 22  Rep. Marjorie Taylor Greene, a Georgia Republi...
# 23  The House goes into recess. Lawmakers evacuate...
# 24  Fox News host Laura Ingraham, who promoted man...
# 25  Trump’s former acting chief of staff Mick Mulv...
# 26  Trump tweets that the rioters should 'stay pea...
# 27  Some of the first Capitol windows are smashed ...
# 28  A group of Oath Keepers – a far-right extremis...
# 29  Pro-Trump rioter Ashli Babbitt is fatally shot...
# 30  Pro-Trump rioters invade the Senate floor and ...
# 31  Donald Trump Jr. texts Meadows, 'He’s got to c...
# 32  Trump speaks on the phone with House Minority ...
# 33  White House aides draft a statement for Trump ...
# 34  Former Trump chief of staff Reince Priebus tex...
# 35  Trump tweets that his supporters at the Capito...
# 36  Ivanka Trump, the President’s daughter and sen...
# 37  Fox News host Sean Hannity, who promoted many ...
# 38  Trump heads to the Rose Garden to film a recor...
# 39                                                NaN
# 40  Trump Jr. texts Meadows, 'We need an oval addr...
# 41  Biden delivers a televised address, saying Cap...
# 42  Trump tweets out a video, where he tells the r...
# 43  A bipartisan group of congressional leaders – ...
# 44  A curfew goes into effect in Washington, DC, a...
# 45  Trump tweets that 'these are the things and ev...
# 46  Trump retires for the night to the White House...
# 47  Giuliani leaves a voicemail for Tuberville, th...
# 48  Trump’s former campaign manager Brad Parscale ...
# 49  US Capitol Police announces that the Capitol b...
# 50  Trump speaks on the phone with Giuliani for ni...
# 51                              The House reconvenes.
# 52  Miller, the Trump campaign spokesman, calls Tr...
# 53  The Senate votes to reject the objection raise...
# 54  Trump speaks with former White House strategis...
# 55  Trump talks to Hannity for eight minutes, acco...
# 56  The House votes to reject the objection raised...

# %%
# extract the events from the 'event' column and store them in a list
events_cnn = time_line_cnn['event'].str.split('/').str[-1].str.upper().str.replace('_', ' ').tolist()


time_dict = {}
for t in events_cnn:
    time_dict[t] = True

unique_event_cnn = [t for t in time_dict.keys()]

# print the events list
print(unique_event_cnn)
# Out:
# ['E CNN 1', 'E CNN 2', 'E CNN 3', 'E CNN 4', 'E CNN 5', 'E CNN 6', 'E CNN 7', 'E CNN 8', 'E CNN 9', 'E CNN 10', 'E CNN 11', 'E CNN 12', 'E CNN 13', 'E CNN 14', 'E CNN 15', 'E CNN 16', 'E CNN 17', 'E CNN 18', 'E CNN 19', 'E CNN 20', 'E CNN 21', 'E CNN 22', 'E CNN 23', 'E CNN 24', 'E CNN 25', 'E CNN 26', 'E CNN 27', 'E CNN 28', 'E CNN 29', 'E CNN 30', 'E CNN 31', 'E CNN 32', 'E CNN 33', 'E CNN 34', 'E CNN 36', 'E CNN 37', 'E CNN 38', 'E CNN 39', 'E CNN 40', 'E CNN 41', 'E CNN 42', 'E CNN 43', 'E CNN 44', 'E CNN 45', 'E CNN 46', 'E CNN 47', 'E CNN 48', 'E CNN 49', 'E CNN 50', 'E CNN 51', 'E CNN 52', 'E CNN 53', 'E CNN 54', 'E CNN 55', 'E CNN 56', 'E CNN 57', 'E CNN 58']

# %%
import datetime

# assuming your original dataset is stored in a pandas dataframe called df
# convert datetime column to datetime type
time_line_cnn['datetime'] = pd.to_datetime(time_line_cnn['datetime'])

# create empty lists for storing the dates and labels
dates_cnn = []
labels_cnn = []
times_cnn = []


for index, row in time_line_cnn.iterrows():
    # append the date to the dates list
    dates_cnn.append(row['datetime'].date())
    # append the label to the labels list
    labels_cnn.append(row['event'])
    # print the time of the datetime
    times_cnn.append(row['datetime'].strftime('%H:%M:%S'))
    #print(row['datetime'].strftime('%H:%M:%S'))
labels_cnn = ['{0:%d %b %Y}:\n{1}'.format(d, l) for l, d in zip (labels_fox, dates_fox)]

time_dict_cnn = {}
for t in times_cnn:
    time_dict_cnn[t] = True

unique_time_cnn = [t for t in time_dict_cnn.keys()]

print(unique_time_cnn)
# Out:
# ['07:30:00', '09:24:00', '09:52:00', '10:00:00', '10:15:00', '10:47:00', '11:20:00', '12:00:00', '13:00:00', '13:10:00', '13:19:00', '13:25:00', '13:39:00', '14:00:00', '14:03:00', '14:13:00', '14:14:00', '14:15:00', '14:24:00', '14:26:00', '14:28:00', '14:30:00', '14:32:00', '14:35:00', '14:38:00', '14:39:00', '14:40:00', '14:44:00', '14:45:00', '14:53:00', '15:00:00', '15:09:00', '15:13:00', '15:15:00', '15:31:00', '16:03:00', '16:05:00', '16:15:00', '16:17:00', '16:45:00', '18:00:00', '18:01:00', '18:27:00', '19:02:00', '19:14:00', '20:00:00', '20:39:00', '21:02:00', '21:23:00', '22:11:00', '22:19:00', '23:08:00', '23:10:00']

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta
import seaborn as sns


unique_events = set(unique_event_cnn)

colors_test = sns.color_palette('bright', len(unique_events))

colors = {}
for i, event in enumerate(unique_events):
    colors[event] = colors_test[i]

        
datetimes = [datetime.strptime(time, '%H:%M:%S') for time in unique_time_cnn]


fig, ax = plt.subplots(figsize=(18,0.75))


colors_list = [colors[event] for event in unique_event_cnn]
ax.scatter(datetimes, [0.5] * len(datetimes), color='blue')



ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlim(datetime.strptime('08:00:00', '%H:%M:%S'), datetime.strptime('23:59:00', '%H:%M:%S'))
ax.set_xlabel('Time of Day Capitol Attack CNN News')


ax.set_yticks([])
ax.set_yticklabels([])

ax.set_title('Timeline Plot CNN news')


plt.show()
